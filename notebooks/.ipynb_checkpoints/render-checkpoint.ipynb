# %%
# %pip install polus
# Out:
# ...
#   Using cached polus-0.1.8-py3-none-any.whl (57 kB)
# ...
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/9a/06/e4ec2a321e57c03b7e9345d709d554a52c33760e5015fdff0919d9459af0/transformers-4.35.0-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for tensorflow-addons from https://files.pythonhosted.org/packages/3e/fa/d96de90170a6ee777884dfc05a2e7115e171a504230669711e94fcf5c304/tensorflow_addons-0.22.0-cp310-cp310-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for wandb from https://files.pythonhosted.org/packages/1c/5e/0362fa88679852c7fd3ac85ee5bd949426c4a51a61379010d4089be6d7ac/wandb-0.15.12-py3-none-any.whl.metadata
# ...

# %%
from polus import render
from urllib.parse import urlparse
from pathlib import Path

# Embeds a render into Jupyter notebooks at https://render.ci.ncats.io/
# render()

# Renders a zarr file hosted locally at "C:\Users\JeffChen\OneDrive - Axle Informatics\Documents\zarr files\pyramid.zarr"
# render(Path(r"/Users/antoinegerardin/Documents/data/argo/temp/jobs/precomputeslide/human_ht29_colon_cancer_1_images_x00_y03_p0(0-5)_c0"))
render(Path(r"/Users/antoinegerardin/Documents/data/precompute-slide-plugin/nist-mist-dataset/out/img_r00(1-5)_c00(1-5)"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/antoinegerardin/Documents/projects/image-workflows/notebooks/.ipynb_checkpoints/render-checkpoint.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/antoinegerardin/Documents/projects/image-workflows/notebooks/.ipynb_checkpoints/render-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from polus import render
#       <a href='vscode-notebook-cell:/Users/antoinegerardin/Documents/projects/image-workflows/notebooks/.ipynb_checkpoints/render-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from urllib.parse import urlparse
#       <a href='vscode-notebook-cell:/Users/antoinegerardin/Documents/projects/image-workflows/notebooks/.ipynb_checkpoints/render-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from pathlib import Path
#
# ...
